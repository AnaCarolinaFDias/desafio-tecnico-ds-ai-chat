# %%
import json
from langchain.document_loaders import CSVLoader
from langchain.llms import OpenAI
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
import pandas as pd


# 1. Carregar os dados
file = 'inputs/OutdoorClothingCatalog_1000.csv'
loader = CSVLoader(file_path=file, encoding="utf-8")
docs = loader.load()

documents_dict = [{doc.page_content} for doc in docs]

# %%
# 2. Definir o LLM e criar o prompt
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

prompt_template = """
You are a product classification assistant. Below are details about a product from an outdoor clothing catalog. 
The dataset contains structured information about outdoor products, including clothing and accessories, 
with attributes such as name and huge description.

Product details:
Product Name: {product_name}
Description: {description}

Classify this product into categories:

Return only the categories as a valid JSON list, in this format:
["Category1", "Category2", "Category3"]
Do not add any other text, only the JSON list.
"""

prompt = PromptTemplate(
    input_variables=["product_name", "description"],
    template=prompt_template
)

# 3. Criar o pipeline de classificação
chain = LLMChain(llm=llm, prompt=prompt)

# 4. Aplicar classificação nos dados e salvar resultados
classified_products = []
names = []
descriptions = []

for docs in documents_dict:
    for element in docs:
        match = re.search(r'name: (.*?)\n', element, re.IGNORECASE)
        if match:
            product_name = match.group(1)  # Extract the matched name

        match = re.search(r'description: (.*?)\n', element, re.IGNORECASE)
        if match:
            description = match.group(1)  # Extract the matched name


        names.append(product_name)
        descriptions.append(description)

        classification = chain.run({
            "product_name": product_name,
            "description": description,
        })
        
        # Print the model's output to debug
        print("Classification output:", classification)

        # Attempt to parse it as JSON only if it's valid
        try:
            categories = json.loads(classification)
        except json.JSONDecodeError:
            print("Error decoding JSON from the classification output.")
            categories = []

    classified_products.append(categories)


data = [names, descriptions, classified_products]
# Out:
# Classification output: ["Footwear", "Casual Shoes", "Women's Shoes"]
# Classification output: ["Pet Accessories", "Dog Mats", "Home & Garden"]
# Classification output: ["Clothing", "Swimwear", "Infant and Toddler"]
# Classification output: ["Swimwear", "Tankini", "Watersports Clothing"]
# Classification output: ["Clothing", "Pants", "Outdoor Gear"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Gloves", "Outdoor Gear"]
# Classification output: ["Clothing", "Women's Clothing", "Sweatshirts"]
# Classification output: ["Clothing", "Outerwear", "Fleece Jackets"]
# Classification output: ["Camping Equipment", "Outdoor Furniture", "Tables"]
# Classification output: ["Clothing", "Loungewear", "Sweaters"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Bedding", "Home Textiles", "Flannel Sheets"]
# Classification output: ["Clothing", "Outerwear", "Shirts"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Kayaks", "Water Sports", "Outdoor Recreation"]
# Classification output: ["Clothing", "Hoodies", "Hunting Gear"]
# Classification output: ["Furniture", "Outdoor Furniture", "Sofas"]
# Classification output: ["Water Sports", "Stand Up Paddleboarding", "Inflatable Boards"]
# Classification output: ["Outdoor Equipment", "Water Sports", "Stand Up Paddleboards"]
# Classification output: ["Outdoor Gear", "Hydration Packs", "Water Sports"]
# Classification output: ["Clothing", "Outdoor Apparel", "Sweaters"]
# Classification output: ["Clothing", "Pants", "Sweatpants"]
# Classification output: ["Bags", "Outdoor Accessories", "Water-Resistant Gear"]
# Classification output: ["Outdoor Gear", "Totes", "Water-Resistant Accessories"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Dog Accessories", "Outdoor Gear", "Waterfowl Hunting Equipment"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Backpacks", "School Supplies", "Outdoor Accessories"]
# Classification output: ["Clothing", "Kids' Clothing", "Fleece"]
# Classification output: ["Furniture", "Home Decor", "Accent Tables"]
# Classification output: ["Footwear", "Moccasins", "Heritage Clothing"]
# Classification output: ["Footwear", "Moccasins", "Heritage Clothing"]
# Classification output: ["Footwear", "Hunting Boots", "Outdoor Clothing"]
# Classification output: ["Outdoor Equipment", "Water Sports", "Tubing Accessories"]
# Classification output: ["Electronics", "Communication Devices", "Outdoor Gear"]
# Classification output: ["Clothing", "Sweaters", "Fleece"]
# Classification output: ["Footwear", "Slippers", "Women's Clothing"]
# Classification output: ["Footwear", "Outdoor Clothing", "Moccasins"]
# Classification output: ["Footwear", "Sandals", "Comfort Shoes"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Gear"]
# Classification output: ["Tents", "Tent Accessories", "Camping Gear"]
# Classification output: ["Footwear", "Running Shoes", "Women's Shoes"]
# Classification output: ["Footwear", "Athletic Shoes", "Women's Shoes"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Clothing"]
# Classification output: ["Footwear", "Kids' Clothing", "Outdoor Accessories"]
# Classification output: ["Clothing", "Shorts", "Fishing Apparel"]
# Classification output: ["Clothing", "Trousers", "Fishing Apparel"]
# Classification output: ["Clothing", "Shirts", "Polo Shirts"]
# Classification output: ["Outdoor Gear", "Hydration", "Water Bottles"]
# Classification output: ["Sunglasses", "Outdoor Accessories", "Eye Protection"]
# Classification output: ["Footwear", "Trail Running Shoes", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Headwear", "Sun Protection"]
# Classification output: ["Clothing", "Footwear", "Accessories"]
# Classification output: ["Clothing", "Outdoor Gear", "Accessories"]
# Classification output: ["Clothing", "Sweaters", "Cashmere"]
# Classification output: ["Coolers", "Outdoor Gear", "Camping Accessories"]
# Classification output: ["Backpacks", "Travel Gear", "Outdoor Accessories"]
# Classification output: ["Clothing", "Swimwear", "Outdoor Accessories"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Footwear", "Slippers", "Women's Clothing"]
# Classification output: ["Clothing", "Tops", "Layering"]
# Classification output: ["Clothing", "Gloves", "Outdoor Accessories"]
# Classification output: ["Footwear", "Children's Clothing", "Slippers"]
# Classification output: ["Clothing", "Outerwear", "Fleece Jackets"]
# Classification output: ["Clothing", "Sweaters", "Fleece"]
# Classification output: ["Clothing", "Pants", "Convertible Pants"]
# Classification output: ["Footwear", "Men's Clothing", "Outdoor Gear"]
# Classification output: ["Clothing", "Outerwear", "Vests"]
# Classification output: ["Footwear", "Kids' Clothing", "Rain Gear"]
# Classification output: ["Clothing", "Jackets", "Kids' Outdoor Gear"]
# Classification output: ["Footwear", "Rain Gear", "Kids' Clothing"]
# Classification output: ["Clothing", "Loungewear", "Knitwear"]
# Classification output: ["Bags", "Briefcases", "Leather Accessories"]
# Classification output: ["Footwear", "Men's Clothing", "Outdoor Gear"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Clothing", "Sweaters", "Vests"]
# Classification output: ["Women's Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Shorts", "Men's Apparel"]
# Classification output: ["Clothing", "Outerwear", "Ponchos"]
# Classification output: ["Clothing", "Accessories", "Outdoor Gear"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Clothing", "Accessories", "Neckwear"]
# Classification output: ["Hair Styling Tools", "Beauty Accessories", "Personal Care"]
# Classification output: ["Footwear", "Outdoor Clothing", "Cold Weather Gear"]
# Classification output: ["Clothing", "Shirts", "Women's Apparel"]
# Classification output: ["Clothing", "Outerwear", "Hoodies"]
# Classification output: ["Watches", "GPS Devices", "Running Accessories"]
# Classification output: ["Outdoor Equipment", "Hunting Gear", "Knives"]
# Classification output: ["Footwear", "Boots", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking Boots", "Men's Outdoor Clothing"]
# Classification output: ["Footwear", "Boots", "Waterproof Boots"]
# Classification output: ["Clothing", "Underwear", "Men's Apparel"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Child Carrier", "Backpacks", "Outdoor Gear"]
# Classification output: ["Footwear", "Ice Skates", "Men's Sports Equipment"]
# Classification output: ["Paddles", "Kayaking Equipment", "Outdoor Recreation"]
# Classification output: ["Outdoor Equipment", "Snowshoeing", "Kids' Outdoor Gear"]
# Classification output: ["Footwear", "Men's Shoes", "Slip-Ons"]
# Classification output: ["Footwear", "Outdoor Gear", "Kids' Outdoor Equipment"]
# Classification output: ["Cameras", "Outdoor Equipment", "Hunting Accessories"]
# Classification output: ["Clothing", "Base Layer", "Kids' Outdoor Gear"]
# Classification output: ["Clothing", "Jackets", "Outdoor Gear"]
# Classification output: ["Footwear", "Hiking Boots", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Clothing", "Pants", "Hunting Apparel"]
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Clothing", "T-Shirts", "Casual Wear"]
# Classification output: ["Clothing", "Women's Clothing", "Underwear"]
# Classification output: ["Pet Accessories", "Dog Supplies", "Collars"]
# Classification output: ["Boys' Clothing", "Activewear", "Pullover"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Gear"]
# Classification output: ["Footwear", "Slippers", "Men's Clothing"]
# Classification output: ["Clothing", "Jackets", "Men's Apparel"]
# Classification output: ["Clothing", "Socks", "Footwear"]
# Classification output: ["Clothing", "Kids' Clothing", "Outdoor Gear"]
# Classification output: ["Tents", "Camping Gear", "Outdoor Equipment"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Accessories", "Outdoor Gear"]
# Classification output: ["Outdoor Equipment", "Lighting", "Hunting Accessories"]
# Classification output: ["Clothing", "Accessories", "Outdoor Gear"]
# Classification output: ["Clothing", "Pants", "Capri Pants"]
# Classification output: ["Clothing", "Accessories", "Winter Wear"]
# Classification output: ["Footwear", "Sandals", "Women's Accessories"]
# Classification output: ["Fishing", "Fly Rods", "Outdoor Equipment"]
# Classification output: ["Outdoor Furniture", "Patio Furniture", "Recliners"]
# Classification output: ["Clothing", "Pants", "Base Layer"]
# Classification output: ["Outdoor Equipment", "Fishing Gear", "Accessories"]
# Classification output: ["Fishing Equipment", "Fly Rods", "Outdoor Gear"]
# Classification output: ["Clothing", "Jackets", "Girls' Outdoor Clothing"]
# Classification output: ["Clothing", "Shirts", "Plaid Shirts"]
# Classification output: ["Watches", "Fitness Accessories", "Outdoor Gear"]
# Classification output: ["Clothing", "Pants", "Denim"]
# Classification output: ["Footwear", "Women's Shoes", "Casual Shoes"]
# Classification output: ["Clothing", "Hats", "Hunting Accessories"]
# Classification output: ["Binoculars", "Outdoor Equipment", "Hunting Accessories"]
# Classification output: ["Clothing", "Thermal Wear", "Women's Apparel"]
# Classification output: ["Clothing", "Hats", "Outdoor Accessories"]
# Classification output: ["Clothing", "Accessories", "Mittens"]
# Classification output: ["Outdoor Equipment", "Archery", "Family Activities"]
# Classification output: ["Clothing", "Hats", "Outdoor Accessories"]
# Classification output: ["Clothing", "Accessories", "Outdoor Gear"]
# Classification output: ["Women's Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Kids' Clothing", "T-Shirts"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Sunglasses", "Outdoor Accessories", "Polarized Eyewear"]
# Classification output: ["Footwear", "Sandals", "Men's Outdoor Clothing"]
# Classification output: ["Clothing", "Sweatshirts", "Outdoor Apparel"]
# Classification output: ["Footwear", "Slippers", "Indoor Clothing"]
# Classification output: ["Clothing", "Swimwear", "Tops"]
# Classification output: ["Footwear", "Outdoor Clothing", "Winter Gear"]
# Classification output: ["Clothing", "Tops", "Long-Sleeve Shirts"]
# Classification output: ["Clothing", "Outdoor Apparel", "Men's Clothing"]
# Classification output: ["Footwear", "Slippers", "Men's Clothing"]
# Classification output: ["Clothing", "Shirts", "Women's Clothing"]
# Classification output: ["Clothing", "Outerwear", "Vests"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Clothing", "Socks", "Men's Apparel"]
# Classification output: ["Clothing", "Outdoor Apparel", "Cycling Shorts"]
# Classification output: ["Jackets", "Outerwear", "Utility Clothing"]
# Classification output: ["Food Containers", "Outdoor Accessories", "Camping Gear"]
# Classification output: ["Footwear", "Hiking Boots", "Insulated Boots"]
# Classification output: ["Clothing", "Gloves", "Outdoor Gear"]
# Classification output: ["Clothing", "Outerwear", "Hoodies"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Gear"]
# Classification output: ["Bedding", "Home Decor", "Outdoor Inspired"]
# Classification output: ["Clothing", "Outerwear", "Cardigans"]
# Classification output: ["Clothing", "Sweaters", "Tunic Sweaters"]
# Classification output: ["Camping Chairs", "Outdoor Furniture", "Camping Gear"]
# Classification output: ["Footwear", "Sandals", "Women's Outdoor Clothing"]
# Classification output: ["Blankets", "Outdoor Gear", "Camping Accessories"]
# Classification output: ["Footwear", "Outdoor Gear", "Hiking Shoes"]
# Classification output: ["Footwear", "Kids' Clothing", "Outdoor Accessories"]
# Classification output: ["Clothing", "Outerwear", "Kids' Apparel"]
# Classification output: ["Clothing", "Shirts", "Casual Wear"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Footwear", "Athletic Shoes", "Casual Shoes"]
# Classification output: ["Bedding", "Home Textiles", "Comforter Covers"]
# Classification output: ["Bags", "Insulated Bags", "Outdoor Accessories"]
# Classification output: ["Ski Equipment", "Outdoor Accessories", "Winter Sports Gear"]
# Classification output: ["Clothing", "Shirts", "Flannel Shirts"]
# Classification output: ["Backpacks", "Outdoor Gear", "Men's Clothing"]
# Classification output: ["Backpacks", "Outdoor Gear", "Day Packs"]
# Classification output: ["Paddles", "Kayaking", "Water Sports"]
# Classification output: ["Clothing", "Shirts", "Rugby Shirts"]
# Classification output: ["Backpacks", "Travel Gear", "Outdoor Accessories"]
# Classification output: ["Clothing", "Base Layer", "Long Sleeve"]
# Classification output: ["Clothing", "Vests", "Women's Apparel"]
# Classification output: ["Clothing", "Jackets", "Insulated Jackets"]
# Classification output: ["Footwear", "Hiking", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking Gear", "Outdoor Accessories"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Footwear", "Casual Shoes", "Leather Shoes"]
# Classification output: ["Clothing", "Outerwear", "Vests"]
# Classification output: []
# Classification output: ["Accessories", "Waist Packs", "Travel Gear"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Clothing", "Outerwear", "Cardigans"]
# Classification output: ["Trekking Poles", "Outdoor Gear", "Hiking Accessories"]
# Classification output: ["Jackets", "Outdoor Clothing", "Waterproof Clothing"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Footwear", "Walking Shoes", "Outdoor Accessories"]
# Classification output: ["Home Protection", "Outdoor Accessories", "Expert Support Services"]
# Classification output: ["Footwear", "Outdoor Shoes", "Men's Shoes"]
# Classification output: ["Fishing Equipment", "Rods", "Outdoor Gear"]
# Classification output: ["Clothing", "Sweaters", "Women's Apparel"]
# Classification output: ["Footwear", "Hiking Boots", "Outdoor Gear"]
# Classification output: ["Clothing", "Hats", "Kids' Outdoor Gear"]
# Classification output: ["Clothing", "Sweaters", "Outdoor Apparel"]
# Classification output: ["Footwear", "Men's Clothing", "Casual Shoes"]
# Classification output: ["Clothing", "Swimwear", "Bikini Tops"]
# Classification output: ["Clothing", "Accessories", "Gloves"]
# Classification output: ["Clothing", "Socks", "Hiking Gear"]
# Classification output: ["Binoculars", "Outdoor Equipment", "Hiking Accessories"]
# Classification output: ["Clothing", "Sweaters", "Merino Wool"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Swimwear", "Tops", "Tankinis"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Clothing", "Outerwear", "Rain Gear"]
# Classification output: ["Jackets", "Outdoor Clothing", "Men's Apparel"]
# Classification output: ["Footwear", "Trail Shoes", "Women's Shoes"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Clothing", "Jackets", "Men's Apparel"]
# Classification output: ["Clothing", "Outerwear", "Shirts"]
# Classification output: ["Child Carrier", "Outdoor Gear", "Toddler Accessories"]
# Classification output: ["Footwear", "Boots", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking Boots", "Outdoor Clothing"]
# Classification output: ["Footwear", "Outdoor Clothing", "Cold Weather Gear"]
# Classification output: ["Clothing", "Polo Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Camping Gear", "Travel Accessories", "Outdoor Equipment"]
# Classification output: ["Camping Gear", "Outdoor Accessories", "Travel Accessories"]
# Classification output: ["Child Carrier", "Outdoor Gear", "Travel Accessories"]
# Classification output: ["Accessories", "Wallets", "Outdoor Gear"]
# Classification output: ["Footwear", "Hiking Gear", "Children's Outdoor Equipment"]
# Classification output: ["Footwear", "Casual Shoes", "Men's Shoes"]
# Classification output: ["Clothing", "Outdoor Apparel", "Hiking Gear"]
# Classification output: ["Footwear", "Hiking Shoes", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Trekking Poles", "Hiking Gear", "Outdoor Equipment"]
# Classification output: ["Clothing", "Pants", "Jeans"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Footwear", "Hunting Boots", "Men's Outdoor Clothing"]
# Classification output: ["Swimwear", "Women's Clothing", "Outdoor Apparel"]
# Classification output: ["Clothing", "Safety Gear", "Outdoor Accessories"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Outdoor Gear", "Hydration", "Water Bottles"]
# Classification output: ["Women's Clothing", "Jackets", "Rainwear"]
# Classification output: ["Footwear", "Slippers", "Kids' Clothing"]
# Classification output: ["Footwear", "Kids' Clothing", "Slippers"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Outdoor Gear", "Camping Accessories", "Hammock Accessories"]
# Classification output: ["Clothing", "Outdoor Apparel", "Sun Protection"]
# Classification output: ["Camping Gear", "Hammocks", "Outdoor Accessories"]
# Classification output: ["Footwear", "Kids' Outdoor Gear", "Hunting Accessories"]
# Classification output: ["Footwear", "Boot Liners", "Men's Accessories"]
# Classification output: ["Footwear", "Wading Boots", "Outdoor Clothing"]
# Classification output: ["Camping Gear", "Lighting", "Outdoor Accessories"]
# Classification output: ["Footwear", "Outdoor Clothing", "Trekking Boots"]
# Classification output: ["Footwear", "Hiking Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Backpacks", "Rolling Backpacks", "Outdoor Gear"]
# Classification output: ["Outdoor Equipment", "Tools", "Sharpening Supplies"]
# Classification output: ["Clothing", "Vests", "Outdoor Apparel"]
# Classification output: ["Bags", "Briefcases", "Outdoor Accessories"]
# Classification output: ["Jackets", "Outerwear", "Men's Clothing"]
# Classification output: ["Pet Accessories", "Dog Training", "Collars"]
# Classification output: ["Clothing", "Jackets", "Outdoor Apparel"]
# Classification output: ["Footwear", "Trail Running", "Men's Outdoor Clothing"]
# Classification output: ["Camping Equipment", "Tents", "Outdoor Gear"]
# Classification output: ["Footwear", "Hiking", "Men's Outdoor Clothing"]
# Classification output: ["Hammocks", "Hammock Accessories", "Outdoor Gear"]
# Classification output: ["Outdoor Equipment", "Skiing", "Bindings"]
# Classification output: ["Clothing", "Jackets", "Girls' Outdoor Clothing"]
# Classification output: ["Footwear", "Boots", "Women's Clothing"]
# Classification output: ["Clothing", "Outerwear", "Vests"]
# Classification output: ["Clothing", "Swimwear", "Girls' Clothing"]
# Classification output: ["Outdoor Furniture", "Footstools", "Adirondack Furniture"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Outdoor Gear", "Backpacks", "Women's Clothing"]
# Classification output: ["Outdoor Furniture", "Benches", "Mudroom Furniture"]
# Classification output: ["Swimwear", "Bikinis", "Women's Clothing"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Swimwear", "Women's Clothing", "Reversible Clothing"]
# Classification output: ["Clothing", "Accessories", "Headwear"]
# Classification output: ["Swimwear", "Women's Clothing", "Tankini"]
# Classification output: ["Clothing", "Swimwear", "Women's Apparel"]
# Classification output: ["Clothing", "Pants", "Activewear"]
# Classification output: ["Clothing", "Pants", "Activewear"]
# Classification output: ["Clothing", "Outerwear", "Parka"]
# Classification output: ["Clothing", "Cycling", "Shorts"]
# Classification output: ["Clothing", "Swimwear", "Sun Protection"]
# Classification output: ["Backpacks", "Women's Outdoor Gear", "Day Packs"]
# Classification output: ["Sleeping Bags", "Camping Gear", "Outdoor Equipment"]
# Classification output: ["Clothing", "Shorts", "Women's Outdoor Apparel"]
# Classification output: ["Clothing", "Hoodies", "Hunting Apparel"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Footwear", "Hiking Shoes", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Socks", "Women's Apparel"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Camping Gear", "Cots", "Outdoor Equipment"]
# Classification output: ["Outdoor Gear", "Camping Equipment", "Accessories"]
# Classification output: ["Fishing", "Fly Fishing", "Fishing Accessories"]
# Classification output: ["Clothing", "Outerwear", "Hunting Gear"]
# Classification output: ["Jackets", "Outerwear", "Insulated Clothing"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Footwear", "Kids' Clothing", "Rain Gear"]
# Classification output: ["Sunglasses", "Outdoor Accessories", "Eyewear"]
# Classification output: ["Jackets", "Outerwear", "Insulated Clothing"]
# Classification output: ["Hats", "Outdoor Accessories", "Clothing"]
# Classification output: ["Accessories", "Headwear", "Hats"]
# Classification output: ["Clothing", "T-Shirts", "Men's Clothing"]
# Classification output: ["Outdoor Accessories", "Fishing Gear", "Vehicle Organizers"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: []
# Classification output: ["Footwear", "Trekking Boots", "Outdoor Clothing"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Clothing", "Jackets", "Women's Apparel"]
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Backpacks", "Outdoor Gear", "Hiking Equipment"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Footwear", "Kids' Clothing", "Winter Gear"]
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Footwear", "Hiking Shoes", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Sweaters", "Casual Wear"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Outdoor Gear", "Trousers"]
# Classification output: ["Footwear", "Moccasins", "Men's Shoes"]
# Classification output: ["Outdoor Furniture", "Adirondack Chairs", "Patio & Garden"]
# Classification output: ["Outdoor Furniture", "Chairs", "Adirondack Chairs"]
# Classification output: ["Clothing", "Pants", "Denim"]
# Classification output: ["Clothing", "Shirts", "Flannel Shirts"]
# Classification output: ["Clothing", "Pants", "Casual Wear"]
# Classification output: ["Clothing", "Headwear", "Winter Accessories"]
# Classification output: ["Swimwear", "Women's Clothing", "Outdoor Apparel"]
# Classification output: ["Footwear", "Hiking Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Clothing Accessories", "Belts", "Men's Fashion"]
# Classification output: ["Footwear", "Running Shoes", "Men's Shoes"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Jackets", "Outdoor Gear"]
# Classification output: ["Clothing", "Shorts", "Athletic Wear"]
# Classification output: ["Clothing", "Swimwear", "Outdoor Accessories"]
# Classification output: ["Clothing", "T-Shirts", "Casual Wear"]
# Classification output: ["Clothing", "Jackets", "Men's Apparel"]
# Classification output: ["Clothing", "Shirts", "Dress Shirts"]
# Classification output: ["Footwear", "Kids' Clothing", "Rain Gear"]
# Classification output: ["Clothing", "Pants", "Jeans"]
# Classification output: ["Footwear", "Hiking Shoes", "Kids' Outdoor Gear"]
# Classification output: ["Clothing", "Pants", "Denim"]
# Classification output: ["Hiking Gear", "Outdoor Accessories", "Skiing Equipment"]
# Classification output: ["Kids' Clothing", "Backpacks", "Outdoor Accessories"]
# Classification output: ["Footwear", "Hiking Boots", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Cycling", "Shorts"]
# Classification output: ["Clothing", "Cycling", "Liners"]
# Classification output: ["Clothing", "Tops", "Polo Shirts", "Women's Apparel"]
# Classification output: ["Clothing", "Sweaters", "Women's Apparel"]
# Classification output: ["Clothing", "Tops", "Polo Shirts"]
# Classification output: ["Home Decor", "Cushion Covers", "Outdoor Accessories"]
# Classification output: ["Fishing", "Fly Fishing", "Fishing Accessories"]
# Classification output: ["Clothing", "Children's Clothing", "T-Shirts"]
# Classification output: ["Footwear", "Boots", "Men's Clothing"]
# Classification output: ["Clothing", "Jackets", "Hooded Jackets"]
# Classification output: ["Camping Gear", "Cookware", "Coffee Makers"]
# Classification output: ["Clothing", "Shorts", "Women's Apparel"]
# Classification output: ["Bags", "Totes", "Outdoor Accessories"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Footwear", "Women's Shoes", "Moccasins"]
# Classification output: ["Clothing", "T-Shirts", "Outdoor Apparel"]
# Classification output: ["Backpacks", "Totes", "Outdoor Accessories"]
# Classification output: ["Outdoor Furniture", "Patio Tables", "Weather-Resistant Furniture"]
# Classification output: ["Clothing", "T-Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Clothing", "Hoodies", "Women's Apparel"]
# Classification output: ["Clothing", "T-Shirts", "Girls' Apparel"]
# Classification output: []
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Socks", "Kids' Outdoor Gear"]
# Classification output: ["Bags", "Outdoor Accessories", "Utility Totes"]
# Classification output: ["Backpacks", "Outdoor Gear", "Waterproof Clothing"]
# Classification output: ["Camping Gear", "Backpacks", "Outdoor Equipment"]
# Classification output: ["Footwear", "Hiking Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Footwear", "Sandals", "Kids' Outdoor Gear"]
# Classification output: ["Footwear", "Hiking Boots", "Outdoor Gear"]
# Classification output: ["Footwear", "Hiking Boots", "Men's Outdoor Clothing"]
# Classification output: ["Clothing", "T-Shirts", "Men's Apparel"]
# Classification output: ["Clothing", "Outdoor Apparel", "Performance Wear"]
# Classification output: ["Clothing", "Tops", "Sleeveless Shirts"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Clothing", "Pants", "Jeans"]
# Classification output: ["Clothing", "Tanks", "Outdoor Apparel"]
# Classification output: ["Clothing", "Tunic", "Linen Apparel"]
# Classification output: ["Clothing", "Activewear", "Leggings"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Footwear", "Hiking", "Outdoor Clothing"]
# Classification output: ["Clothing", "Activewear", "Girls' Apparel"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Clothing", "Outerwear", "Insulated Jackets"]
# Classification output: ["Tools", "Multitools", "Outdoor Accessories"]
# Classification output: ["Outdoor Furniture", "Beach Gear", "Chairs"]
# Classification output: ["Footwear", "Slides", "Women's Outdoor Clothing"]
# Classification output: ["Coolers", "Outdoor Accessories", "Picnic Gear"]
# Classification output: ["Footwear", "Winter Boots", "Women's Clothing"]
# Classification output: ["Sunglasses", "Outdoor Accessories", "Polarized Eyewear"]
# Classification output: ["Clothing", "Shirts", "Flannel Shirts"]
# Classification output: ["Clothing", "Outerwear", "Hoodies"]
# Classification output: ["Camping Gear", "Outdoor Accessories", "Drinkware"]
# Classification output: ["Camping Gear", "Outdoor Accessories", "Drinkware"]
# Classification output: ["Footwear", "Children's Clothing", "Slippers"]
# Classification output: ["Footwear", "Hunting Gear", "Outdoor Clothing"]
# Classification output: ["Clothing Accessories", "Outdoor Gear", "Collectibles"]
# Classification output: ["Clothing", "Underwear", "Outdoor Accessories"]
# Classification output: ["Clothing", "Tops", "Shirts"]
# Classification output: ["Clothing", "Outerwear", "Rain Jackets"]
# Classification output: ["Clothing", "Cycling Apparel", "Women's Clothing"]
# Classification output: ["Clothing", "Pants", "Outdoor Gear"]
# Classification output: ["Clothing", "Pants", "Sweatpants"]
# Classification output: ["Clothing", "Pants", "Base Layer"]
# Classification output: ["Footwear", "Outdoor Clothing", "Hiking Shoes"]
# Classification output: ["Footwear", "Winter Boots", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Camping Gear", "Utensils", "Outdoor Accessories"]
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Kayaks", "Fishing Gear", "Outdoor Recreation"]
# Classification output: ["Clothing", "Outerwear", "Fleece Jackets"]
# Classification output: ["Footwear", "Sandals", "Kids' Outdoor Gear"]
# Classification output: ["Clothing", "Jackets", "Fleece"]
# Classification output: ["Clothing", "Shorts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Women's Clothing", "Underwear"]
# Classification output: ["Clothing", "Outdoor Apparel", "Shorts"]
# Classification output: ["Home Decor", "Furniture", "Storage Solutions"]
# Classification output: ["Home Decor", "Storage Solutions", "Coat Racks"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Footwear", "Sandals", "Women's Outdoor Clothing"]
# Classification output: ["Shelters", "Outdoor Gear", "Sun Protection"]
# Classification output: ["Clothing", "Outerwear", "Vests"]
# Classification output: ["Footwear", "Sandals", "Kids' Clothing"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Footwear", "Boots", "Outdoor Clothing"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Clothing", "Fishing", "Outdoor Accessories"]
# Classification output: ["Clothing", "Pants", "Casual Wear"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Hats", "Outdoor Clothing", "Accessories"]
# Classification output: ["Clothing", "Pants", "Casual Wear"]
# Classification output: ["Furniture", "Living Room", "Chairs"]
# Classification output: ["Clothing", "Activewear", "Tights"]
# Classification output: ["Binoculars", "Outdoor Equipment", "Optics"]
# Classification output: ["Outdoor Equipment", "Binoculars", "Hiking Accessories"]
# Classification output: ["Clothing", "Pants", "Outdoor Apparel"]
# Classification output: ["Pet Supplies", "Dog Beds", "Outdoor Furniture"]
# Classification output: ["Footwear", "Hiking Shoes", "Women's Outdoor Clothing"]
# Classification output: ["Clothing Accessories", "Outdoor Gear", "Collectibles"]
# Classification output: ["Clothing", "Base Layer", "Trousers"]
# Classification output: ["Clothing", "Outerwear", "Fleece"]
# Classification output: ["Clothing", "Fleece", "Outdoor Accessories"]
# Classification output: ["Footwear", "Slippers", "Women's Clothing"]
# Classification output: ["Clothing", "Shorts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Pants", "Chinos"]
# Classification output: ["Women's Clothing", "Jackets", "Insulated Jackets"]
# Classification output: ["Clothing", "Outerwear", "Fishing Accessories"]
# Classification output: ["Clothing", "Pants", "Men's Apparel"]
# Classification output: ["Clothing", "Sweaters", "Outdoor Apparel"]
# Classification output: ["Clothing", "Kids", "Footwear"]
# Classification output: ["Clothing", "Shirts", "Casual Wear"]
# Classification output: ["Clothing", "Outerwear", "Kids' Apparel"]
# Classification output: ["Clothing", "Kids' Clothing", "Sweaters"]
# Classification output: ["Outdoor Gear", "Water Sports", "Snorkeling Equipment"]
# Classification output: ["Footwear", "Sandals", "Women's Shoes"]
# Classification output: ["Swimwear", "Tankini", "Women's Clothing"]
# Classification output: ["Clothing", "Activewear", "Men's Apparel"]
# Classification output: ["Clothing", "Skirts", "Women's Apparel"]
# Classification output: ["Footwear", "Boots", "Men's Clothing"]
# Classification output: ["Clothing", "Outerwear", "Coats"]
# Classification output: ["Footwear", "Outdoor Clothing", "Wading Boots"]
# Classification output: ["Clothing", "Shirts", "Long Sleeve Shirts"]
# Classification output: ["Outerwear", "Parka", "Down Jacket"]
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Clothing", "Jackets", "Hunting Apparel"]
# Classification output: ["Clothing", "Jackets", "Women's Apparel"]
# Classification output: ["Camping Gear", "Cooking Equipment", "Backpacking Supplies"]
# Classification output: ["Clothing", "Cycling", "Shorts"]
# Classification output: ["Outdoor Equipment", "Fishing Accessories", "Fly Fishing Gear"]
# Classification output: ["Footwear", "Hiking Boots", "Men's Outdoor Clothing"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Bags", "Outdoor Accessories", "Hiking Gear"]
# Classification output: ["Clothing", "T-Shirts", "Fishing Apparel"]
# Classification output: ["Clothing", "Outdoor Apparel", "Fishing Gear"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Shirts", "Dress Shirts"]
# Classification output: ["Clothing", "T-Shirts", "Casual Wear"]
# Classification output: ["Clothing", "Socks", "Accessories"]
# Classification output: ["Clothing", "Paddling Gear", "Waterproof Pants"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Outdoor Gear", "Gaiters"]
# Classification output: ["Footwear", "Accessories", "Outdoor Clothing"]
# Classification output: ["Clothing", "Accessories", "Winter Sports"]
# Classification output: ["Fishing", "Fly Fishing", "Fishing Accessories"]
# Classification output: ["Clothing", "Shorts", "Men's Outdoor Apparel"]
# Classification output: ["Home Goods", "Towels", "Eco-Friendly Products"]
# Classification output: ["Camping Equipment", "Cooking Gear", "Backpacking Stoves"]
# Classification output: ["Clothing", "Hats", "Kids' Apparel"]
# Classification output: ["Clothing", "Activewear", "Shorts"]
# Classification output: ["Clothing", "Girls' Clothing", "Shirts"]
# Classification output: ["Backpacks", "Outdoor Gear", "Girls' Clothing"]
# Classification output: ["Clothing", "Headwear", "Outdoor Accessories"]
# Classification output: ["Outdoor Equipment", "Water Sports", "Kayaks"]
# Classification output: []
# Classification output: ["Clothing", "Shorts", "Outdoor Apparel"]
# Classification output: ["Footwear", "Hiking Shoes", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Footwear", "Hiking Gear"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Clothing", "Waders", "Outdoor Gear"]
# Classification output: ["Footwear", "Hunting Gear", "Outdoor Clothing"]
# Classification output: ["Outerwear", "Jackets", "Hunting Apparel"]
# Classification output: ["Clothing", "Outerwear", "Vests"]
# Classification output: ["Footwear", "Boots", "Outdoor Clothing"]
# Classification output: ["Clothing", "Base Layer", "Pants"]
# Classification output: ["Footwear", "Boots", "Outdoor Accessories"]
# Classification output: ["Clothing", "Jackets", "Outdoor Apparel"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Sweaters", "Casual Wear"]
# Classification output: ["Footwear", "Women's Footwear", "Boots"]
# Classification output: ["Bags", "Outdoor Gear", "Hunting Accessories"]
# Classification output: ["Clothing", "Pants", "Outdoor Gear"]
# Classification output: ["Clothing", "Outerwear", "Infants' and Toddlers' Apparel"]
# Classification output: ["Footwear", "Trail Running Shoes", "Outdoor Clothing"]
# Classification output: ["Clothing", "Hats", "Outdoor Accessories"]
# Classification output: ["Kayaks", "Fishing Equipment", "Outdoor Recreation"]
# Classification output: ["Footwear", "Hiking Shoes", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Shirts", "Men's Clothing", "Outdoor Apparel", "Sun Protection Clothing"]
# Classification output: ["Footwear", "Hiking Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Clothing", "Sweaters", "Outdoor Gear"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Outdoor Equipment", "Binoculars", "Hiking Accessories"]
# Classification output: ["Clothing", "Accessories", "Belts"]
# Classification output: ["Camping Gear", "Cooking Equipment", "Coffee Makers"]
# Classification output: ["Blankets", "Outdoor Accessories", "Cotton Products"]
# Classification output: ["Clothing", "T-Shirts", "Organic Cotton"]
# Classification output: ["Clothing", "Shorts", "Girls' Apparel"]
# Classification output: ["Footwear", "Moccasins", "Outdoor Accessories"]
# Classification output: ["Footwear", "Shoes", "Outdoor Clothing"]
# Classification output: ["Bedding", "Sheet Sets", "Flannel Sheets"]
# Classification output: ["Footwear", "Hiking Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Clothing", "Shorts", "Outdoor Gear"]
# Classification output: ["Luggage", "Duffles", "Travel Accessories"]
# Classification output: ["Clothing", "Accessories", "Fishing Gear"]
# Classification output: ["Bags", "Outdoor Gear", "Hunting Accessories"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Footwear", "Outdoor Gear", "Hiking Accessories"]
# Classification output: ["Clothing", "Skirts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Shirts", "Flannel Shirts"]
# Classification output: ["Outdoor Equipment", "Insect Repellents", "Camping Accessories"]
# Classification output: ["Clothing", "Outdoor Gear", "Gaiters"]
# Classification output: ["Outdoor Recreation", "Winter Sports", "Sleds"]
# Classification output: ["Outdoor Equipment", "Sleds", "Kids' Outdoor Gear"]
# Classification output: ["Hats", "Outdoor Clothing", "Sun Protection Accessories"]
# Classification output: ["Clothing", "Outerwear", "Coats"]
# Classification output: ["Outdoor Clothing", "Hats", "Sun Protection Accessories"]
# Classification output: ["Clothing", "Hats", "Outdoor Accessories"]
# Classification output: ["Outdoor Accessories", "Fishing Gear", "Vehicle Organizers"]
# Classification output: ["Clothing", "T-Shirts", "Outdoor Apparel"]
# Classification output: ["Footwear", "Slides", "Women's Shoes"]
# Classification output: ["Footwear", "Men's Clothing", "Outdoor Accessories"]
# Classification output: ["Footwear", "Slippers", "Kids' Clothing"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Outdoor Equipment", "Water Sports", "Kayaks"]
# Classification output: ["Women's Clothing", "Jackets", "Outdoor Apparel"]
# Classification output: ["Footwear", "Hiking Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Clothing", "Shorts", "Summer Wear"]
# Classification output: ["Outdoor Furniture", "Patio Furniture", "Settee"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Pants", "Denim"]
# Classification output: ["Clothing", "Shirts", "Insulated Wear"]
# Classification output: ["Tents", "Camping Gear", "Outdoor Accessories"]
# Classification output: ["Clothing", "Jackets", "Men's Apparel"]
# Classification output: ["Jackets", "Women's Clothing", "Outdoor Apparel"]
# Classification output: ["Clothing", "Sweaters", "Outdoor Apparel"]
# Classification output: ["Footwear", "Boots", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking Boots", "Women's Outdoor Clothing"]
# Classification output: ["Furniture", "Sofas", "Sleepers"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Camping Gear", "Lighting", "Outdoor Equipment"]
# Classification output: ["Clothing", "Cycling", "Shorts"]
# Classification output: ["Footwear", "Hiking", "Outdoor Gear"]
# Classification output: ["Clothing", "Jackets", "Women's Apparel"]
# Classification output: ["Clothing", "Activewear", "Vests"]
# Classification output: ["Footwear", "Insulated Boots", "Outdoor Clothing"]
# Classification output: ["Wallets", "Accessories", "Outdoor Gear"]
# Classification output: ["Clothing", "Outerwear", "Hunting Apparel"]
# Classification output: ["Clothing", "Activewear", "Tops"]
# Classification output: ["Footwear", "Kids' Clothing", "Outdoor Gear"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Footwear", "Trekking Shoes", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Pants", "Men's Apparel"]
# Classification output: ["Outdoor Gear", "Cargo Boxes", "Vehicle Accessories"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Gear"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking Gear", "Outdoor Accessories"]
# Classification output: ["Fishing Accessories", "Leaders", "Fluorocarbon"]
# Classification output: ["Clothing", "Jackets", "Accessories"]
# Classification output: ["Clothing", "Swimwear", "Tanks"]
# Classification output: ["Clothing", "Pants", "Winter Wear"]
# Classification output: ["Clothing", "Sweaters", "Men's Apparel"]
# Classification output: ["Footwear", "Hiking Boots", "Outdoor Gear"]
# Classification output: ["Tools", "Multitools", "Outdoor Accessories"]
# Classification output: ["Clothing", "Swimwear", "Girls' Apparel"]
# Classification output: ["Clothing", "Shirts", "Men's Apparel"]
# Classification output: ["Clothing", "Men's Clothing", "Shirts"]
# Classification output: ["Footwear", "Kids' Clothing", "Outdoor Accessories"]
# Classification output: ["Clothing", "Tunic", "Outdoor Apparel"]
# Classification output: ["Clothing", "Shirts", "Casual Wear"]
# Classification output: ["Fishing", "Fly Fishing", "Fishing Gear"]
# Classification output: ["Bedding", "Quilts", "Home Decor"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Clothing", "Outdoor Apparel", "Footwear"]
# Classification output: ["Home Decor", "Furniture", "Coat Stands"]
# Classification output: ["Footwear", "Men's Shoes", "Oxfords"]
# Classification output: ["Footwear", "Men's Shoes", "Oxfords"]
# Classification output: ["Clothing", "Accessories", "Winter Wear"]
# Classification output: ["Clothing", "Outdoor Apparel", "Girls' Clothing"]
# Classification output: ["Clothing", "Outerwear", "Fleece"]
# Classification output: ["Camping Gear", "Cooking Equipment", "Outdoor Accessories"]
# Classification output: ["Footwear", "Trekking Boots", "Outdoor Clothing"]
# Classification output: ["Clothing", "Outerwear", "Fleece"]
# Classification output: ["Clothing", "Outerwear", "Fleece"]
# Classification output: ["Outdoor Gear", "Knives", "Folding Knives"]
# Classification output: ["Footwear", "Sandals", "Outdoor Gear"]
# Classification output: ["Outdoor Gear", "Shelters", "Insect Protection"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Jackets", "Outerwear", "Insulated Clothing"]
# Classification output: ["Footwear", "Hiking Boots", "Men's Outdoor Clothing"]
# Classification output: ["Footwear", "Sneakers", "Casual Shoes"]
# Classification output: ["Clothing", "Outdoor Gear", "Hiking Apparel"]
# Classification output: ["Electronics", "Outdoor Gear", "Emergency Preparedness"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Kids' Clothing", "Fleece Pullover"]
# Classification output: ["Footwear", "Rain Gear", "Women's Clothing"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Clothing", "T-Shirts", "Short-Sleeve Tops"]
# Classification output: ["Kids' Clothing", "Outdoor Gear", "Bicycles"]
# Classification output: ["Clothing Accessories", "Outdoor Gear", "Collectibles"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Clothing"]
# Classification output: ["Footwear", "Winter Boots", "Women's Clothing"]
# Classification output: ["Footwear", "Sandals", "Outdoor Clothing"]
# Classification output: ["Shelters", "Canopies", "Outdoor Equipment"]
# Classification output: ["Clothing", "Sweaters", "Outdoor Apparel"]
# Classification output: ["Outdoor Equipment", "Water Sports", "Kayaking"]
# Classification output: ["Footwear", "Casual Shoes", "Outdoor Clothing"]
# Classification output: ["Clothing", "Shirts", "Men's Apparel"]
# Classification output: ["Footwear", "Boots", "Women's Clothing"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Clothing"]
# Classification output: ["Fishing Accessories", "Tools", "Outdoor Equipment"]
# Classification output: ["Water Sports", "Paddleboards", "Outdoor Recreation"]
# Classification output: ["Clothing", "Shorts", "Outdoor Apparel"]
# Classification output: ["Bags", "Totes", "Outdoor Accessories"]
# Classification output: ["Backpacks", "Hiking Gear", "Outdoor Equipment"]
# Classification output: ["Camping Gear", "Sleeping Pads", "Outdoor Equipment"]
# Classification output: ["Outdoor Furniture", "Camping Gear", "Chairs"]
# Classification output: ["Clothing", "Swimwear", "Women's Swimwear"]
# Classification output: ["Clothing", "Swimwear", "Shorts"]
# Classification output: ["Clothing", "Swimwear", "Men's Apparel"]
# Classification output: ["Outdoor Furniture", "Beach Gear", "Chairs"]
# Classification output: ["Outdoor Furniture", "Patio Furniture", "Loungers"]
# Classification output: []
# Classification output: []
# Classification output: ["Clothing", "Tops", "Sleeveless Tees"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Footwear", "Hiking Boots", "Men's Outdoor Clothing"]
# Classification output: ["Kayaks", "Water Sports", "Outdoor Recreation"]
# Classification output: ["Clothing", "Fleece", "Men's Apparel"]
# Classification output: ["Clothing", "Outdoor Apparel", "Hiking Gear"]
# Classification output: ["Clothing", "Outerwear", "Fleece Coats"]
# Classification output: ["Clothing", "Outerwear", "Insulated Jackets"]
# Classification output: ["Clothing", "Pants", "Capri Pants"]
# Classification output: ["Swimwear", "Bikini Tops", "Water Sports Clothing"]
# Classification output: ["Footwear", "Slippers", "Outdoor Accessories"]
# Classification output: ["Clothing", "Outerwear", "Parka"]
# Classification output: ["Clothing", "Sweaters", "Tunic"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Kayaks", "Outdoor Recreation", "Water Sports"]
# Classification output: ["Clothing", "Cycling Apparel", "Men's Clothing"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Clothing", "Cycling Apparel", "Shorts"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Bedding", "Home Decor", "Textiles"]
# Classification output: ["Clothing", "Cycling", "Knickers"]
# Classification output: ["Clothing", "Swimwear", "Men's Apparel"]
# Classification output: ["Clothing", "Outdoor Gear", "Fishing Accessories"]
# Classification output: ["Clothing", "Sweaters", "Outdoor Apparel"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Accessories", "Wallets", "Outdoor Gear"]
# ...
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Clothing", "Swimwear", "Girls' Clothing"]
# Classification output: ["Outdoor Furniture", "Chairs", "Camping Gear"]
# Classification output: ["Clothing", "Shorts", "Girls' Apparel"]
# Classification output: ["Lighting", "Camping Gear", "Accessories"]
# Classification output: ["Clothing", "Pants", "Outdoor Gear"]
# Classification output: ["Outdoor Equipment", "Bike Accessories", "Bike Racks"]
# Classification output: ["Bedding", "Home Textiles", "Comforter Covers"]
# Classification output: ["Clothing", "Sweaters", "Men's Apparel"]
# Classification output: ["Footwear Accessories", "Insoles", "Comfort Products"]
# Classification output: ["Footwear", "Kids' Clothing", "Winter Gear"]
# Classification output: ["Clothing", "Socks", "Men's Accessories"]
# Classification output: ["Clothing", "Outerwear", "Parka"]
# Classification output: ["Footwear", "Sandals", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Sweaters", "Men's Apparel"]
# Classification output: ["Footwear", "Kids' Outdoor Clothing", "Hiking Shoes"]
# Classification output: ["Footwear", "Kids' Clothing", "Winter Gear"]
# Classification output: ["Outdoor Gear", "Water Purification", "Camping Accessories"]
# Classification output: ["Backpacks", "Women's Outdoor Gear", "Hiking Equipment"]
# Classification output: ["Backpacks", "Outdoor Gear", "Travel Accessories"]
# Classification output: ["Clothing", "Undergarments", "Outdoor Gear"]
# Classification output: ["Headwear", "Sun Protection", "Cooling Accessories"]
# Classification output: ["Home Decor", "Rugs", "Textiles"]
# Classification output: ["Clothing", "Hoodies", "Girls' Apparel"]
# Classification output: ["Clothing", "Outerwear", "Cardigans"]
# Classification output: ["Clothing", "Swimwear", "Tanks"]
# Classification output: ["Clothing", "Socks", "Men's Accessories"]
# Classification output: ["Home Decor", "Pillows", "Outdoor Lifestyle"]
# Classification output: ["Coolers", "Picnic Accessories", "Outdoor Gear"]
# Classification output: ["Clothing", "Activewear", "Shorts"]
# Classification output: ["Footwear", "Slippers", "Women's Clothing"]
# Classification output: ["Hats", "Outdoor Clothing", "Accessories"]
# Classification output: ["Clothing", "Outerwear", "Hoodies"]
# Classification output: ["Swimwear", "Tanksuit", "Outdoor Clothing"]
# Classification output: ["Clothing", "Swimwear", "Outdoor Accessories"]
# Classification output: ["Bags", "Backpacks", "Travel Accessories"]
# Classification output: ["Footwear", "Sandals", "Men's Outdoor Clothing"]
# Classification output: ["Clothing", "T-Shirts", "Men's Apparel"]
# Classification output: ["Towels", "Beach Accessories", "Travel Gear"]
# Classification output: ["Clothing", "Socks", "Accessories"]
# Classification output: ["Clothing", "Hoodies", "Outdoor Apparel"]
# Classification output: ["Paddles", "Water Sports", "Outdoor Equipment"]
# Classification output: ["Clothing", "Accessories", "Outdoor Gear"]
# Classification output: ["Clothing", "Outerwear", "Vests"]
# Classification output: ["Clothing", "Outerwear", "Pullover"]
# Classification output: ["Sleeping Pads", "Camping Gear", "Outdoor Equipment"]
# Classification output: ["Outdoor Accessories", "Umbrella Stands", "Weights"]
# Classification output: ["Footwear", "Hiking Boots", "Men's Outdoor Clothing"]
# Classification output: ["Outdoor Gear", "Backpacks", "Women's Clothing"]
# Classification output: ["Footwear", "Snow Boots", "Outdoor Clothing"]
# Classification output: ["Clothing", "Pants", "Base Layers"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Clothing", "Shorts", "Women's Apparel"]
# Classification output: ["Clothing", "Accessories", "Hats"]
# Classification output: ["Footwear", "Outdoor Equipment", "Winter Sports"]
# Classification output: ["Footwear", "Sandals", "Outdoor Accessories"]
# Classification output: ["Outerwear", "Jackets", "Down Jackets"]
# Classification output: ["Clothing", "Outerwear", "Hats"]
# Classification output: ["Backpacks", "Hunting Gear", "Outdoor Accessories"]
# Classification output: ["Backpacks", "Hunting Gear", "Outdoor Accessories"]
# Classification output: ["Outdoor Gear", "Cycling Accessories", "Hunting Equipment"]
# Classification output: ["Clothing", "Pants", "Outdoor Gear"]
# Classification output: ["Clothing", "Shirts", "Short-Sleeve Shirts"]
# Classification output: ["Clothing", "Sweatshirts", "Organic Cotton"]
# Classification output: ["Accessories", "Wallets", "Leather Goods"]
# Classification output: ["Footwear", "Men's Shoes", "Trekking Shoes"]
# Classification output: ["Coolers", "Outdoor Equipment", "Camping Accessories"]
# Classification output: ["Clothing", "Outerwear", "Cardigans"]
# Classification output: ["Backpacks", "Outdoor Gear", "Camping Equipment"]
# Classification output: ["Outdoor Gear", "Storage Solutions", "Waterproof Bags"]
# Classification output: ["Clothing", "Outdoor Shorts", "Men's Apparel"]
# Classification output: ["Clothing", "Men's Clothing", "Outdoor Apparel"]
# Classification output: ["Towels", "Eco-Friendly Products", "Outdoor Accessories"]
# Classification output: ["Kids' Clothing", "Sleepwear", "Loungewear"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Clothing", "Women's Clothing", "Jeans"]
# Classification output: ["Jackets", "Insulated Jackets", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking", "Outdoor Clothing"]
# Classification output: ["Footwear", "Hiking", "Kids"]
# Classification output: ["Camping Gear", "Outdoor Clothing", "Blankets"]
# Classification output: ["Clothing", "Vests", "Outerwear"]
# Classification output: ["Clothing", "Pants", "Jeans"]
# Classification output: ["Clothing", "Men's Clothing", "Pants"]
# Classification output: ["Clothing", "Shorts", "Swimwear"]
# Classification output: ["Clothing", "Headwear", "Outdoor Accessories"]
# Classification output: ["Clothing", "Outerwear", "Pullover"]
# Classification output: ["Clothing", "Outerwear", "Fleece Shirts"]
# Classification output: ["Clothing", "Activewear", "Bottoms"]
# Classification output: ["Clothing", "Shorts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Men's Clothing", "Outdoor Apparel"]
# Classification output: ["Clothing", "Jackets", "Insulated Jackets"]
# Classification output: ["Clothing", "Trousers", "Insulated Wear"]
# Classification output: ["Fishing Accessories", "Travel Gear", "Outdoor Equipment"]
# Classification output: ["Clothing", "Socks", "Outdoor Accessories"]
# Classification output: ["Outdoor Equipment", "Trekking Poles", "Hiking Accessories"]
# Classification output: ["Fishing Accessories", "Outdoor Gear", "Rod Cases"]
# Classification output: ["Footwear", "Kids' Clothing", "Outdoor Accessories"]
# Classification output: ["Footwear", "Kids' Clothing", "Outdoor Gear"]
# Classification output: ["Clothing", "Outdoor Apparel", "Fishing Gear"]
# Classification output: ["Clothing", "Footwear", "Outdoor Gear"]
# Classification output: ["Clothing", "T-Shirts", "Long Sleeve Tees"]
# Classification output: ["Clothing", "Swimwear", "Girls' Apparel"]
# Classification output: ["Clothing", "Outdoor Apparel", "Skirts"]
# Classification output: ["Clothing", "Pants", "Summer Wear"]
# Classification output: ["Footwear", "Sandals", "Summer Wear"]
# Classification output: ["Jackets", "Outerwear", "Down Insulation"]
# Classification output: ["Clothing", "Outerwear", "Sweaters"]
# Classification output: ["Footwear", "Trail Running Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Hats", "Sun Protection", "Women's Accessories"]
# Classification output: ["Clothing", "Sweatshirts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Outerwear", "Fleece"]
# Classification output: ["Outdoor Equipment", "Binoculars", "Optics"]
# Classification output: ["Clothing", "Outerwear", "Fleece Jackets"]
# Classification output: ["Footwear", "Hiking Boots", "Outdoor Clothing"]
# Classification output: ["Outdoor Equipment", "Sports & Games", "Accessories"]
# Classification output: ["Clothing", "T-Shirts", "Athletic Wear"]
# Classification output: ["Outdoor Gear", "Backpacks", "Women's Clothing"]
# Classification output: ["Kids' Clothing", "Outerwear", "Ski Jackets"]
# Classification output: ["Outdoor Gear", "Fishing Accessories", "Storage Solutions"]
# Classification output: ["Footwear", "Outdoor Gear", "Hiking Accessories"]
# Classification output: ["Footwear", "Sandals", "Outdoor Accessories"]
# Classification output: ["Footwear", "Sandals", "Outdoor Accessories"]
# Classification output: ["Clothing", "Outerwear", "Fleece"]
# Classification output: ["Clothing", "Outerwear", "Fleece"]
# Classification output: ["Clothing", "Shirts", "Men's Apparel"]
# Classification output: ["Clothing", "Accessories", "Mittens"]
# Classification output: ["Tools", "Outdoor Equipment", "Accessories"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Footwear", "Kids' Clothing", "Rain Gear"]
# Classification output: ["Clothing", "Outdoor Apparel", "Vests"]
# Classification output: ["Women's Clothing", "Jackets", "Water Sports Apparel"]
# Classification output: ["Clothing", "Sweaters", "Women's Apparel"]
# Classification output: ["Clothing", "Outerwear", "Water Sports"]
# Classification output: ["Clothing", "Fleece", "Outdoor Apparel"]
# Classification output: ["Jackets", "Fleece", "3-in-1 Outerwear"]
# Classification output: ["Clothing", "Jackets", "Outdoor Apparel"]
# Classification output: ["Backpacks", "Hiking Gear", "Outdoor Accessories"]
# Classification output: ["Sleeping Bags", "Camping Gear", "Outdoor Equipment"]
# Classification output: ["Camping Gear", "Sleeping Bags", "Outdoor Equipment"]
# Classification output: ["Clothing", "Outerwear", "Vests"]
# Classification output: ["Footwear", "Fitness Shoes", "Women's Shoes"]
# Classification output: ["Footwear", "Hiking Shoes", "Men's Outdoor Clothing"]
# Classification output: ["Footwear", "Slippers", "Men's Clothing"]
# Classification output: ["Footwear", "Winter Boots", "Outdoor Clothing"]
# Classification output: ["Footwear", "Winter Gear", "Accessories"]
# Classification output: ["Clothing", "Pants", "Denim"]
# Classification output: ["Hats", "Women's Accessories", "Outdoor Clothing"]
# Classification output: ["Clothing", "Accessories", "Headwear"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Tops", "Short-Sleeve Shirts"]
# Classification output: ["Sleeping Bags", "Camping Gear", "Outdoor Equipment"]
# Classification output: ["Clothing", "Outerwear", "Cardigans"]
# Classification output: ["Sunglasses", "Women's Accessories", "Outdoor Gear"]
# Classification output: ["Binoculars", "Outdoor Equipment", "Hiking Accessories"]
# Classification output: ["Outdoor Equipment", "Kayak Accessories", "Transport Gear"]
# Classification output: ["Clothing", "Socks", "Hiking Gear"]
# Classification output: ["Clothing", "Socks", "Kids' Apparel"]
# Classification output: ["Clothing", "Shorts", "Kids' Apparel"]
# Classification output: ["Clothing", "Shorts", "Activewear"]
# Classification output: ["Pet Clothing", "Outdoor Gear", "Insect Protection"]
# Classification output: ["Outdoor Gear", "Knives", "Folding Knives"]
# Classification output: ["Outdoor Furniture", "Loungers", "Adirondack Chairs"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Clothing", "Tops", "Shirts"]
# Classification output: ["Footwear", "Rain Gear", "Kids' Clothing"]
# Classification output: ["Footwear", "Kids", "Rain Gear"]
# Classification output: ["Clothing", "Outdoor Gear", "Water Sports Equipment"]
# Classification output: ["Clothing", "Accessories", "Mittens"]
# Classification output: ["Clothing", "Accessories", "Water Sports"]
# Classification output: ["Clothing", "Pants", "Hiking Gear"]
# Classification output: ["Clothing", "Skates", "Outdoor Accessories"]
# Classification output: ["Footwear", "Sandals", "Outdoor Clothing"]
# Classification output: ["Clothing", "Socks", "Women's Apparel"]
# Classification output: ["Clothing", "Outerwear", "Jackets"]
# Classification output: ["Outdoor Gear", "Camping Equipment", "Storage Solutions"]
# Classification output: ["Footwear", "Sneakers", "High-Top Shoes"]
# Classification output: ["Sunglasses", "Fishing Accessories", "Outdoor Gear"]
# Classification output: ["Kids' Accessories", "Outdoor Gear", "Hydration"]
# Classification output: ["Clothing", "Hats", "Kids' Accessories"]
# Classification output: ["Outdoor Gear", "Camping Accessories", "Blankets"]
# Classification output: ["Footwear", "Hiking Boots", "Women's Outdoor Clothing"]
# Classification output: ["Outdoor Accessories", "Hiking Gear", "Knife Holsters"]
# Classification output: ["Fishing Accessories", "Outdoor Gear", "Waist Packs"]
# Classification output: ["Clothing", "Shirts", "Women's Clothing"]
# Classification output: ["Fishing Accessories", "Outdoor Gear", "Waist Packs"]
# Classification output: ["Clothing", "Shirts", "Men's Clothing"]
# Classification output: ["Clothing", "Dresses", "Summer Wear"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Clothing", "Children's Clothing", "Snow Pants"]
# Classification output: ["Clothing", "Jackets", "Hunting Gear"]
# Classification output: ["Clothing", "Outdoor Apparel", "Thermal Tops"]
# Classification output: ["Sunglasses", "Women's Accessories", "Outdoor Gear"]
# Classification output: ["Footwear", "Hiking Boots", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Hoodies", "Outdoor Gear"]
# Classification output: ["Outdoor Furniture", "Patio Umbrellas", "Garden Accessories"]
# Classification output: ["Clothing", "Outerwear", "Ski Jackets"]
# Classification output: ["Clothing", "Sweaters", "Cardigans"]
# Classification output: ["Footwear", "Hunting Gear", "Outdoor Clothing"]
# Classification output: ["Camping Gear", "Tents", "Tent Accessories"]
# Classification output: ["Outdoor Equipment", "Camping Gear", "Tent Accessories"]
# Classification output: ["Hammocks", "Outdoor Gear", "Camping Accessories"]
# Classification output: ["Footwear", "Hiking Boots", "Women's Outdoor Clothing"]
# Classification output: ["Clothing", "Shirts", "Outdoor Apparel"]
# Classification output: ["Jackets", "Outerwear", "Men's Clothing"]
# Classification output: ["Blankets", "Outdoor Accessories", "Wool Products"]
# Classification output: ["Hiking Gear", "Outdoor Accessories", "Clothing"]
# Classification output: ["Jackets", "3-in-1 Jackets", "Outdoor Clothing"]
# Classification output: ["Backpacks", "Outdoor Gear", "Waterproof Clothing"]
# Classification output: ["Outdoor Furniture", "Garden Furniture", "Benches"]
# Classification output: ["Footwear", "Sandals", "Kids' Clothing"]
# Classification output: ["Bags", "Duffles", "Outdoor Accessories"]
# Classification output: ["Clothing", "Pants", "Women's Apparel"]
# Classification output: ["Clothing", "T-Shirts", "Women's Apparel"]
# Classification output: ["Footwear", "Men's Shoes", "Casual Shoes"]
# Classification output: ["Bedding", "Quilts", "Home Decor"]
# Classification output: ["Footwear", "Men's Shoes", "Casual Shoes"]
# Classification output: ["Fishing", "Outdoor Equipment", "Surf Fishing Rods"]
# Classification output: ["Outdoor Gear", "Multitools", "Camping Accessories"]
# Classification output: ["Clothing", "Shorts", "Women's Apparel"]
# Classification output: ["Backpacks", "Outdoor Gear", "Camping Equipment"]
# Classification output: ["Footwear", "Hiking Shoes", "Outdoor Clothing"]
# Classification output: ["Clothing", "Pants", "Denim"]
# Classification output: ["Fishing", "Fly Fishing", "Fishing Rods"]
# Classification output: ["Backpacks", "Outdoor Gear", "School Supplies"]
# Classification output: ["Clothing", "Swimwear", "Women's Swimwear"]
# Classification output: ["Clothing", "Outerwear", "Insulated Jackets"]
# Classification output: ["Clothing", "Men's Clothing", "Jeans"]
# Classification output: ["Clothing", "Outerwear", "Sweaters"]
# Classification output: ["Clothing", "Paddling Gear", "Women's Apparel"]
# Classification output: ["Clothing", "Outerwear", "Hoodies"]
# Classification output: ["Bags", "Crossbody Bags", "Outdoor Accessories"]

# %%
# Combine the lists into a dictionary
data = {
    'names': names,
    'descriptions': descriptions,
    'classified_products': classified_products
}

# Convert the dictionary to a DataFrame
df = pd.DataFrame(data)

# Save the results to a JSON file
results_filename = f"inputs/ProductsCategories_OutdoorClothingCatalog_1000_results.csv"

# Save the DataFrame to a CSV file
df.to_csv(results_filename, index=False)  # `index=False` prevents writing row numbers

print("Documents have been saved to {results_filename}")
# Out:
# Documents have been saved to {results_filename}

# %%
file = 'inputs/OutdoorClothingCatalog_1000.csv'
OutdoorClothingCatalog = pd.read_csv(file)
OutdoorClothingCatalog

file = 'inputs/ProductsCategories_OutdoorClothingCatalog_1000_results.csv'
ProductsCategories_OutdoorClothingCatalog_1000_results = pd.read_csv(file)
ProductsCategories_OutdoorClothingCatalog_1000_results.rename(columns={'names': 'name'}, inplace=True)
ProductsCategories = ProductsCategories_OutdoorClothingCatalog_1000_results[['name','classified_products']]
ProductsCategories

finalDatabase = pd.merge(OutdoorClothingCatalog, ProductsCategories, on='name', how='inner')

# Save the results to a JSON file
results_filename = f"inputs/OutdoorClothingCatalog_1000_withCategories.csv"

# Save the DataFrame to a CSV file
finalDatabase.to_csv(results_filename, index=False)  # `index=False` prevents writing row numbers

print("Documents have been saved to {results_filename}")
# Out:
# Documents have been saved to {results_filename}
